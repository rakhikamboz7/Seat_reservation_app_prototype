# %% [markdown]
# <a href="https://colab.research.google.com/github/rakhikamboz7/Seat_reservation_app_prototype/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/paskhaver/pandas-in-action.git
# Out:
# Cloning into 'pandas-in-action'...
# remote: Enumerating objects: 715, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 715 (delta 113), reused 85 (delta 85), pack-reused 597
# Receiving objects: 100% (715/715), 36.99 MiB | 16.29 MiB/s, done.
# Resolving deltas: 100% (348/348), done.

# %%
import pandas as pd
movies =pd.read_csv("/content/pandas-in-action/chapter_01_introducing_pandas/movies.csv", index_col='Title')
print(movies)
# Out:
#                               Rank           Studio       Gross  Year
# Title
# Avengers: Endgame                1      Buena Vista  $2,796.30   2019
# Avatar                           2              Fox  $2,789.70   2009
# Titanic                          3        Paramount  $2,187.50   1997
# Star Wars: The Force Awakens     4      Buena Vista  $2,068.20   2015
# Avengers: Infinity War           5      Buena Vista  $2,048.40   2018
# ...                            ...              ...         ...   ...
# Yogi Bear                      778  Warner Brothers    $201.60   2010
# Garfield: The Movie            779              Fox    $200.80   2004
# Cats & Dogs                    780  Warner Brothers    $200.70   2001
# The Hunt for Red October       781        Paramount    $200.50   1990
# Valkyrie                       782              MGM    $200.30   2008
#
# [782 rows x 4 columns]

# %%
movies.head()
# Out:
#                               Rank       Studio       Gross  Year
# Title
# Avengers: Endgame                1  Buena Vista  $2,796.30   2019
# Avatar                           2          Fox  $2,789.70   2009
# Titanic                          3    Paramount  $2,187.50   1997
# Star Wars: The Force Awakens     4  Buena Vista  $2,068.20   2015
# Avengers: Infinity War           5  Buena Vista  $2,048.40   2018

# %%
len(movies)
# Out:
# 782

# %%
movies.shape
# Out:
# (782, 4)

# %%
#total number  of cells
movies.size
# Out:
# 3128

# %%
#data types of four column
movies.dtypes
# Out:
# Rank       int64
# Studio    object
# Gross     object
# Year       int64
# dtype: object

# %%
#if we wanted to pull out the  500th movie in the data set, we would target index position 499
movies.iloc[499]
#we know the stream which we want.
# Out:
# Rank           500
# Studio         Fox
# Gross     $288.30
# Year          2018
# Name: Maze Runner: The Death Cure, dtype: object

# %%
#extracts a row by its index label rather its numeric position
movies.loc["101 Dalmatians"]
# Out:
#                 Rank       Studio     Gross  Year
# Title
# 101 Dalmatians   425  Buena Vista  $320.70   1996
# 101 Dalmatians   708  Buena Vista  $215.90   1961

# %%
# what if we wante to see the five  nmovies with the most recent release date?
movies.sort_values(by="Year", ascending = False).head(10)
# Out:
#                                             Rank                  Studio  \
# Title
# Avengers: Endgame                              1             Buena Vista
# John Wick: Chapter 3 - Parabellum            458               Lionsgate
# The Wandering Earth                          114  China Film Corporation
# Toy Story 4                                  198             Buena Vista
# How to Train Your Dragon: The Hidden World   199               Universal
# Pokemon Detective Pikachu                    263         Warner Brothers
# Alita: Battle Angel                          286                     Fox
# Godzilla: King of the Monsters               315         Warner Brothers
# Shazam!                                      340         Warner Brothers
# Dumbo                                        369             Buena Vista
#
#                                                  Gross  Year
# Title
# Avengers: Endgame                           $2,796.30   2019
# ...

# %%
#we can also sort DataFrame by values across multiple columns
movies.sort_values(by=["Studio", "Year"]).head(15)
# Out:
#                           Rank       Studio     Gross  Year
# Title
# The Blair Witch Project    588      Artisan  $248.60   1999
# 101 Dalmatians             708  Buena Vista  $215.90   1961
# The Jungle Book            755  Buena Vista  $205.80   1967
# Who Framed Roger Rabbit    410  Buena Vista  $329.80   1988
# Dead Poets Society         636  Buena Vista  $235.90   1989
# Honey, I Shrunk the Kids   679  Buena Vista  $222.70   1989
# The Little Mermaid         738  Buena Vista  $211.30   1989
# Pretty Woman               234  Buena Vista  $463.40   1990
# Beauty and the Beast       267  Buena Vista  $425.00   1991
# Aladdin                    204  Buena Vista  $504.10   1992
# Sister Act                 647  Buena Vista  $231.60   1992
# The Lion King               42  Buena Vista  $968.50   1994
# Toy Story                  323  Buena Vista  $373.60   1995
# Pocahontas                 386  Buena Vista  $346.10   1995
# The Rock                   399  Buena Vista  $335.10   1996
